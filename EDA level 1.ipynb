# %% [markdown]
#  #...important necessary libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %matplotlib inline

# %%
import zipfile

zip_path = r"C:\Users\DELL\Downloads\archive (4).zip"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    print(zip_ref.namelist())
# Out:
# ['Housing.csv']

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Sample - Superstore.csv", encoding="latin1")

# %% [markdown]
# Initial Inspection ✅

# %%
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cbar=False)
plt.show()

# %% [markdown]
# Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Descriptive Statistics ✅

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Row ID          4997.5000
# Postal Code    56430.5000
# Sales             54.4900
# Quantity           3.0000
# Discount           0.2000
# Profit             8.6665
# dtype: float64

# %%
df.mode
# Out:
# <bound method DataFrame.mode of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# standard deviation

# %%
df.std(numeric_only=True)
# Out:
# Row ID          2885.163629
# Postal Code    32063.693350
# Sales            623.245101
# Quantity           2.225110
# Discount           0.206452
# Profit           234.260108
# dtype: float64

# %% [markdown]
# convert date

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %% [markdown]
# Monthly sales trend

# %%
monthly=df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()

monthly.plot(figsize=(12,5))

plt.title("Monthly Sales")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# # monthly sales incerease during holiday season

# %% [markdown]
# Quartely sales trend

# %%
quarterly=df.groupby(df['Order Date'].dt.to_period('Q'))['Sales'].sum()

quarterly.plot(figsize=(12,5),color='green')

plt.title("Quarterly Sales")

plt.show()

# %%
quarterly=df.groupby(df['Order Date'].dt.to_period('Q'))['Sales'].sum()

quarterly.plot(figsize=(12,5),color='green')

plt.title("Quarterly Sales")

plt.show()

# %%
# quartely sales increase during holiday season

# %% [markdown]
# Top 10 Best Selling Products

# %%
top=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top.plot(kind='barh',figsize=(10,6))

plt.title("Top 10 Products")

plt.show()

# %% [markdown]
# Revenue by Category

# %%
sns.barplot(x='Category',y='Sales',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %% [markdown]
# Correlation Heatmap ✅

# %% [markdown]
# #Example
# Technology contributes the highest revenue

# %%
# correlation Heatmap

# %%
plt.figure(figsize=(8,6))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")

plt.show()

# %% [markdown]
# Sales and Profit have a positive correlation, while Discount negatively impacts Profit.

# %% [markdown]
#  Additional Visualization
# # Correlation Heatmap

# %%
sns.barplot(data=df,
            x="Region",
            y="Profit",
            estimator=sum)

plt.title("Profit by Region")

plt.show()

# %% [markdown]
# The West region generates the highest profit, while some regions have comparatively lower profitability.

# %% [markdown]
# #Observation
#
# Explain positive and negative correlations.

# %% [markdown]
# #  Business Recommendations
#
# Example
#
# Recommendation 1
#
# Increase inventory before holiday seasons.
#
# Recommendation 2
#
# Promote Technology products through marketing campaigns.
#
# Recommendation 3
#
# Reduce excessive discounts on Furniture.

# %% [markdown]
#  ## Business Insights
#
# Example
#
# Technology products generate maximum revenue.
# West region contributes highest sales.
# Holiday months increase sales.
# Furniture has high sales but lower profit.
# Discounts reduce profitability.

# %% [markdown]
# THANKYOU
